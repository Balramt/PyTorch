# %% [markdown]
# <a href="https://colab.research.google.com/github/Balramt/PyTorch/blob/main/experiments/pytorch_nn_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pytorch torch.nn module

# %%
# create model class
import torch
import torch.nn as nn

class model(nn.modules):
  def __init__(self, num_features):
    super().__init__()
    self.linear = nn.Linear(num_features, 1)  #  Input is number of features and output is 1
    self.sigmoid = nn.Sigmoid()
  def forward(self, x):
    out = self.linear(x)
    out = self.sigmoid(out)
    return out

# %%
import torch
import torch.nn as nn

# %%
class MySimpleNN(nn.modules):

  def __init__(self, num_features):

    super().__init__()
    self.linear = nn.Linear(num_features, 1)
    self.sigmoid = nn.Sigmoid()

  def forward(self, features):
    out = self.linear(features)
    out = self.sigmoid(out)
    return out
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12118/405822991.py in <cell line: 0>()
# ----> 1 class MySimpleNN(nn.modules):
#       2
#       3   def __init__(self, num_features):
#       4
#       5     super().__init__()
#
# TypeError: module() takes at most 2 arguments (3 given)
